# %%
import os
import pandas as pd

# %%
def find_lostart_csv(id: int):
    """
    Find the csv file containing the Lost Art ID and return the corresponding dataframe.
    """
    for csv in os.listdir("data/lostart"):
        df = pd.read_csv(f"data/lostart/{csv}", sep=";")

        if df.loc[df["Lost Art ID"] == id].shape[0] > 0:
            break
    
    return csv, df.loc[df["Lost Art ID"] == id]

def remove_leakage(df: pd.DataFrame):
    """
    Remove leakage columns from the dataframe.
    """
    return df.drop(columns=["Inventarnummer/Signatur", "Provenienz", "Literatur / Quelle"])

def get_concatenated_txt(series: pd.Series):
    """
    Concatenate the non-NaN values of a series into a string.
    """
    result = ""
    
    for idx, value in series.items():
        if pd.notna(value):
            result += f"{idx}: {value} "
            result += "\n"
        else:
            result += f"{idx}: "
            result += "\n"
            
    return result

# Lost Art ID: 589708
_, lostart = find_lostart_csv(589708)
lostart = remove_leakage(lostart)
lostart_txt = get_concatenated_txt(lostart.squeeze())

# %%
# Load mnr data
pop = pd.read_excel("data/mnr_20250303_17h40m54s.ods")

# Remove potential leakage columns

def remove_leakage_mnr(df: pd.DataFrame):
    """
    Remove leakage columns from the dataframe.
    """
    leakage_cols = ["HIST4", "LOCA", "NOTE"]
    df = df.drop(columns=leakage_cols)

    unecessary_cols = ["POP_IMPORT", "VIDEO"]
    df = df.drop(columns=unecessary_cols)
    return df


def add_column_with_concatenated_txt(df: pd.DataFrame):
    """
    Add a new column to the dataframe containing the concatenated text of the other columns.
    """
    df["CONCATENATED"] = df.apply(lambda row: get_concatenated_txt(row), axis=1)
    return df

pop = remove_leakage_mnr(pop)
pop = add_column_with_concatenated_txt(pop)

# %%
from Embedding import EmbeddingFromPretrained

# model_name="sentence-transformers/all-mpnet-base-v2"
emb = EmbeddingFromPretrained()

# Get the embedding of the Lost Art text
lostart_emb = emb.get_mean_pooling_embedding(lostart_txt)
lostart_emb
# Out:
# tensor([[-1.5780e-01,  1.1512e-01,  1.6125e-02,  1.3090e-02, -5.2402e-02,
#           1.5398e-01, -3.0527e-02,  1.0796e-01, -4.8301e-02, -9.5199e-02,
#          -4.7553e-02, -6.7236e-02,  2.1684e-02, -4.3447e-02, -2.1051e-01,
#          -5.2413e-02, -8.8275e-02,  4.3779e-02,  4.6275e-02,  4.3512e-02,
#          -7.8799e-02, -6.6008e-02,  3.8625e-02,  9.1215e-02, -3.5481e-02,
#          -3.0292e-02, -1.0008e-01,  6.3713e-03, -4.1287e-02, -2.1866e-02,
#          -2.4563e-02,  9.7806e-02, -2.9754e-02, -4.9153e-02,  6.1578e-02,
#           5.0376e-02, -4.4859e-02, -1.4834e-02, -2.9136e-02, -3.6950e-02,
#          -2.5866e-02, -7.7251e-02, -1.3000e-01,  3.3486e-02,  6.5007e-02,
#           7.3249e-03,  2.5164e-02,  6.6596e-02, -9.8494e-02,  1.9221e-02,
#          -1.6584e-01,  6.9362e-02, -1.4390e-02, -1.1004e-01, -4.5777e-02,
#           3.7522e-02,  2.0026e-02, -1.5729e-03,  6.1697e-02, -2.1725e-02,
#          -6.8505e-03, -1.0328e-02,  1.1591e-01,  2.8048e-03, -1.9847e-03,
#           1.1884e-03, -4.3987e-02, -1.5840e-02,  7.0582e-02]])

# %%
import torch
from sklearn.metrics.pairwise import cosine_similarity

def get_most_similar_text(emb: torch.tensor, embedder, pop: pd.DataFrame):
    """
    Get the most similar text to the given embedding in the given dataframe.
    """

    similarities = pop["CONCATENATED"].apply(lambda x: cosine_similarity(emb, embedder.get_mean_pooling_embedding(x)).item())
    # top 5 most similar
    return pop.loc[similarities.nlargest(10).index]

most_similar = get_most_similar_text(lostart_emb, emb, pop)

# %%
most_similar
# Out:
#            REF  POP_COMMENTAIRES  POP_FLAGS AATT  \
# 1044  JDP-0051               NaN        NaN  NaN
# 2071  MNR00240               NaN        NaN  NaN
# 359   MNR00089               NaN        NaN  NaN
# 1056  JDP-0076               NaN        NaN  NaN
# 1830  MNAM0012               NaN        NaN  NaN
# 1086  JDP-0079               NaN        NaN  NaN
# 1667  ATP00010               NaN        NaN  NaN
# 1001  JDP-0016               NaN        NaN  NaN
# 1669  ATP00012               NaN        NaN  NaN
# 1071  JDP-0080               NaN        NaN  NaN
#
#                                                    AFFE  \
# 1044                                                NaN
# 2071  Paris ; musée du Louvre ; département des Pein...
# 359                                                 NaN
# 1056                                                NaN
# 1830               Paris ; musée national d'art moderne
# 1086                                                NaN
# 1667  Marseille ; musée des civilisations de l'Europ...
# 1001                                                NaN
# 1669  Marseille ; musée des civilisations de l'Europ...
# 1071                                                NaN
#
#                                           ATIT  \
# 1044                                       NaN
# 2071                                   Tournoi
# 359   Portrait d'hommePortrait d'un architecte
# 1056                                       NaN
# 1830            Vue de neige#Rue sous la neige
# 1086                                       NaN
# 1667                                       NaN
# 1001                                       NaN
# 1669                                       NaN
# 1071                                       NaN
#
#                                                    ATTR  \
# 1044                                                NaN
# 2071  MAITRE DE LA NATIVITE DE KARLSRUHE. MAITRE DES...
# 359                                            RIVALZ ?
# 1056                                                NaN
# 1830                                                NaN
# 1086                                                NaN
# 1667                                                NaN
# 1001                                                NaN
# 1669                                                NaN
# 1071                                                NaN
#
#                                                    AUTI                AUTR  \
# 1044  Paysage avec vase de ChrysanthèmesLes Quatre âges      BAUCHANT André
# 2071                                                NaN             Anonyme
# 359                                                 NaN   LONGHI Alessandro
# 1056                                                NaN    PISSARRO Camille
# 1830                                                NaN     UTRILLO Maurice
# 1086                                                NaN       PICASSO Pablo
# 1667                                                NaN             Anonyme
# 1001  Sémaphore avec tourelle pour drapeauGrands bât...  DE CHIRICO Giorgio
# 1669                                                NaN             Anonyme
# 1071                                      Effet de soir       COROT Camille
#
#                                  BASE  ...  \
# 1044  Rose Valland (MNR-Jeu de Paume)  ...
# 2071  Rose Valland (MNR-Jeu de Paume)  ...
# 359   Rose Valland (MNR-Jeu de Paume)  ...
# 1056  Rose Valland (MNR-Jeu de Paume)  ...
# 1830  Rose Valland (MNR-Jeu de Paume)  ...
# 1086  Rose Valland (MNR-Jeu de Paume)  ...
# 1667  Rose Valland (MNR-Jeu de Paume)  ...
# 1001  Rose Valland (MNR-Jeu de Paume)  ...
# 1669  Rose Valland (MNR-Jeu de Paume)  ...
# 1071  Rose Valland (MNR-Jeu de Paume)  ...
#
#                                                    REPR RESUME  \
# 1044                                                NaN    NaN
# 2071  scène (bataille, Moyen Age, équestre, cheval, ...    NaN
# 359   portrait (Ferracina Bartolomeo, homme, de troi...    NaN
# 1056                                                NaN    NaN
# 1830                                                NaN    NaN
# 1086                                                NaN    NaN
# 1667                                                NaN    NaN
# 1001                                                NaN    NaN
# 1669                                                NaN    NaN
# 1071                                                NaN    NaN
#
#                                             SALLES                  SCLE SREP  \
# 1044                                           NaN                   NaN  NaN
# 2071  26/06/2019 : au rez-de-chaussée, salle Linet            15e siècle  NaN
# 359                                            NaN            18e siècle  NaN
# 1056                                           NaN                   NaN  NaN
# 1830                                           NaN  1er quart 20e siècle  NaN
# 1086                                           NaN                   NaN  NaN
# 1667                                           NaN                     ?  NaN
# 1001                                           NaN                   NaN  NaN
# 1669                                           NaN            18e siècle  NaN
# 1071                                           NaN                   NaN  NaN
#
#      STYL SUITE                                     TECH  \
# 1044  NaN   NaN                                      NaN
# 2071  NaN   NaN                            Bois;peinture
# 359   NaN   NaN                 Toile;peinture à l'huile
# 1056  NaN   NaN                                      NaN
# 1830  NaN   NaN                 Toile;peinture à l'huile
# 1086  NaN   NaN                                      NaN
# 1667  NaN   NaN             Cuivre sur âme acier;gravure
# 1001  NaN   NaN                                      NaN
# 1669  NaN   NaN  Bois (acajou ?);cuivre repoussé;gravure
# 1071  NaN   NaN                                      NaN
#
#                                           TITR  \
# 1044                      Dahlias au vase rose
# 2071  Histoire de Camille (panneau de cassone)
# 359           Portrait de Bartolomeo Ferracina
# 1056                   Chemin à travers champs
# 1830              Rue de village sous la neige
# 1086                                     Pomme
# 1667            Plaque pour frapper les tissus
# 1001                           Le Jour de fête
# 1669                                     Canne
# 1071                          Paysage de forêt
#
#                                            CONCATENATED
# 1044  REF: JDP-0051 \nPOP_COMMENTAIRES: \nPOP_FLAGS:...
# 2071  REF: MNR00240 \nPOP_COMMENTAIRES: \nPOP_FLAGS:...
# 359   REF: MNR00089 \nPOP_COMMENTAIRES: \nPOP_FLAGS:...
# 1056  REF: JDP-0076 \nPOP_COMMENTAIRES: \nPOP_FLAGS:...
# 1830  REF: MNAM0012 \nPOP_COMMENTAIRES: \nPOP_FLAGS:...
# 1086  REF: JDP-0079 \nPOP_COMMENTAIRES: \nPOP_FLAGS:...
# 1667  REF: ATP00010 \nPOP_COMMENTAIRES: \nPOP_FLAGS:...
# 1001  REF: JDP-0016 \nPOP_COMMENTAIRES: \nPOP_FLAGS:...
# 1669  REF: ATP00012 \nPOP_COMMENTAIRES: \nPOP_FLAGS:...
# 1071  REF: JDP-0080 \nPOP_COMMENTAIRES: \nPOP_FLAGS:...
#
# [10 rows x 58 columns]
