# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
only_vision = pd.DataFrame({
    'Lost Art ID': [589707, 589708, 614072, 526702, 567247, 429210, 310418, 600027, 323038],
    'rank': [0, 0, 0, 0, 0, 0, 2456, 6, 2456],
    'similarity': [0.543198, 0.644780, 0.557309, 0.593860, 0.610656, 0.610871, 2456.000000, 0.624990, 2456.000000]
})


only_text_miniLM_cls_cross = pd.DataFrame({
    'Lost Art ID': [589707, 589708, 614072, 526702, 567247, 429210, 310418, 600027, 323038],
    'rank': [1, 331, 0, 1, 6, 13, 280, 236, 988],
    'similarity': [0.623045, 0.493014, 0.848318, 0.560747, 0.544725, 0.647239, 2456.000000, 0.616799, 2456.000000]
})
only_text_miniLM_mean_pooling_cross = pd.DataFrame({
    "Lost Art ID": [589707, 589708, 614072, 526702, 567247, 429210, 310418, 600027, 323038],
    "rank": [3, 295, 0, 0, 10, 3, 213, 354, 574],
    "similarity": [0.579145, 0.400840, 0.843475, 0.515210, 0.458551, 0.579718, 0.401431, 0.460439, 0.362674]
})
only_text_miniLM_mean_pooling_concat = pd.DataFrame({
    'Lost Art ID': [589707, 589708, 614072, 526702, 567247, 429210, 310418, 600027, 323038],
    'rank': [2059, 779, 1136, 749, 375, 1955, 1141, 1044, 1403],
    'similarity': [0.307575, 0.725531, 0.620942, 0.665506, 0.735304, 0.375177, 0.498502, 0.625250, 0.540186]
})
only_text_miniLM_cls_concat = pd.DataFrame({
    'Lost Art ID': [589707, 589708, 614072, 526702, 567247, 429210, 310418, 600027, 323038],
    'rank': [0, 1952, 1747, 170, 414, 1322, 2049, 1342, 1011],
    'similarity': [0.758681, 0.339955, 0.333449, 0.441303, 0.442689, 0.423443, 0.404095, 0.407942, 0.532797]
})
only_text_xlm_cls_cross = pd.DataFrame({
    'Lost Art ID': [589707, 589708, 614072, 526702, 567247, 429210, 310418, 600027, 323038],
    'rank': [0, 537, 0, 0, 6, 944, 103, 12, 305],
    'similarity': [0.724306, 0.671577, 0.877679, 0.736989, 0.730592, 0.722152, 0.751914, 0.824832, 0.715107]
})


miniLM_mean_pooling_cross_dino_01 = pd.DataFrame({
    'Lost Art ID': [589707, 589708, 614072, 526702, 567247, 429210, 310418, 600027, 323038],
    'rank': [0, 0, 0, 0, 1, 0, 213, 0, 310],
    'similarity': [0.678585, 0.836303, 0.846620, 0.794325, 0.725964, 0.847768, 0.401431, 0.789457, 0.362674]
})
miniLM_mean_pooling_cross_dino_05 = pd.DataFrame({
    'Lost Art ID': [589707, 589708, 614072, 526702, 567247, 429210, 310418, 600027, 323038],
    'rank': [0, 5, 0, 0, 0, 0, 213, 2, 332],
    'similarity': [0.634389, 0.642764, 0.845223, 0.670274, 0.607114, 0.728635, 0.401431, 0.643227, 0.362674]
})
miniLM_mean_pooling_cross_dino_09 = pd.DataFrame({
    'Lost Art ID': [589707, 589708, 614072, 526702, 567247, 429210, 310418, 600027, 323038],
    'rank': [0, 142, 0, 0, 2, 0, 213, 75, 487],
    'similarity': [0.590194, 0.449225, 0.843825, 0.546223, 0.488264, 0.609501, 0.401431, 0.496996, 0.362674]
})



# Ajoute une colonne "method"
only_vision[['method', 'type']] = ["$\mathbf{dinoV2}$", "vision"]
only_text_miniLM_cls_cross[['method', 'type']] = ["MiniLM (CLS token, cross)", "text"]
only_text_miniLM_mean_pooling_cross[['method', 'type']] = ["$\mathbf{MiniLM}$", "text"]
only_text_miniLM_cls_concat[['method', "type"]] = ["MiniLM (CLS token, concatenate)", "text"]
only_text_miniLM_mean_pooling_concat[['method', "type"]] = ["MiniLM (concatenate)", "text"]
only_text_xlm_cls_cross[['method', "type"]] = ["XLM (CLS token, cross)", "text"]
miniLM_mean_pooling_cross_dino_01[['method', "type"]] = ["$\\beta=0.1$", "multimodal"]
miniLM_mean_pooling_cross_dino_05[['method', "type"]] = ["$\\beta=0.5$", "multimodal"]
miniLM_mean_pooling_cross_dino_09[['method', "type"]] = ["$\\beta=0.9$", "multimodal"]
# Out:
# <>:54: SyntaxWarning: invalid escape sequence '\m'
# <>:56: SyntaxWarning: invalid escape sequence '\m'
# <>:54: SyntaxWarning: invalid escape sequence '\m'
# <>:56: SyntaxWarning: invalid escape sequence '\m'
# /var/folders/v5/_0ss5l5d6nz8d575gs5spbx40000gn/T/ipykernel_14042/3417065247.py:54: SyntaxWarning: invalid escape sequence '\m'
#   only_vision[['method', 'type']] = ["$\mathbf{dinoV2}$", "vision"]
# /var/folders/v5/_0ss5l5d6nz8d575gs5spbx40000gn/T/ipykernel_14042/3417065247.py:56: SyntaxWarning: invalid escape sequence '\m'
#   only_text_miniLM_mean_pooling_cross[['method', 'type']] = ["$\mathbf{MiniLM}$", "text"]

# %%
df_all = pd.concat([only_vision, only_text_miniLM_cls_cross, only_text_miniLM_mean_pooling_cross, only_text_miniLM_cls_concat, only_text_miniLM_mean_pooling_concat, only_text_xlm_cls_cross, miniLM_mean_pooling_cross_dino_01, miniLM_mean_pooling_cross_dino_09], ignore_index=True)

palette = {
    "vision": "skyblue",
    "text": "salmon",
    "multimodal": "lightgreen"
}

# %%
# Display only text type methods

df_all_text = df_all[df_all['type'] == 'text']

# Rename text methods for better readability
df_all_text['method'] = df_all_text['method'].replace({
    "MiniLM (CLS token, cross)": "$\mathbf{MiniLM}$ \n cross comparison \n CLS token",
    "$\mathbf{MiniLM}$": "$\mathbf{MiniLM}$ \n cross comparison \n mean pooling",
    "MiniLM (CLS token, concatenate)": "$\mathbf{MiniLM}$ \n concatenate \n CLS token",
    "MiniLM (concatenate)": "$\mathbf{MiniLM}$ \n concatenate \n mean pooling",
    "XLM (CLS token, cross)": "$\mathbf{XLM-RoBERTa}$ \n cross comparison \n CLS token",
})

plt.figure(figsize=(10, 6))
sns.boxplot(data=df_all_text, x="method", y="rank", hue="type", palette=palette, width=0.4)
plt.yscale("log")
plt.title("Rank of Lost Art ID in Rose Valland")
plt.xlabel("Method")
plt.ylabel("Rank distribution (log scale)")
plt.grid(True, which="both", axis="y")
# plt.legend(title="Type of method")
plt.tight_layout()
plt.legend().remove()
# plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:9: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# <>:11: SyntaxWarning: invalid escape sequence '\m'
# <>:7: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:9: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# <>:11: SyntaxWarning: invalid escape sequence '\m'
# /var/folders/v5/_0ss5l5d6nz8d575gs5spbx40000gn/T/ipykernel_14042/3331751517.py:7: SyntaxWarning: invalid escape sequence '\m'
#   "MiniLM (CLS token, cross)": "$\mathbf{MiniLM}$ \n cross comparison \n CLS token",
# /var/folders/v5/_0ss5l5d6nz8d575gs5spbx40000gn/T/ipykernel_14042/3331751517.py:8: SyntaxWarning: invalid escape sequence '\m'
# ...

# %%
# in text type methods, keep only MiniLM - cross comparison - mean pooling
df_all_text = df_all_text[df_all_text['method'] == "MiniLM"]
df_all = pd.concat([only_vision, only_text_miniLM_mean_pooling_cross,  miniLM_mean_pooling_cross_dino_01, miniLM_mean_pooling_cross_dino_05, miniLM_mean_pooling_cross_dino_09], ignore_index=True)


plt.figure(figsize=(10, 6))
sns.boxplot(data=df_all, x="method", y="rank", hue="type", palette=palette, width=0.4)
plt.yscale("log")
plt.title("Rank of Lost Art ID in Rose Valland")
plt.xlabel("Method")
plt.ylabel("Rank distribution (log scale)")
plt.grid(True, which="both", axis="y")
plt.legend(title="Type of method")
plt.tight_layout()
plt.show()
